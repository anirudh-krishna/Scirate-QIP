# %%
from bs4 import BeautifulSoup as bs
import urllib.request
import difflib
from bs4 import NavigableString
import numpy as np
import operator

# %%
def get_paper_details(url):
    """
    Input: url string for scirate page for a specific paper
    Output: dictionary corresponding to paper with keys authors, scites, title and arxivID
    """
    source = urllib.request.urlopen(url).read()
    soup = bs(source,"html.parser")

    paper = {}
    paper['authors'] = []
    paper['scites'] = []
    paper['title'] = None
    paper['arxivID'] = None

    #Get title
    div_title = soup.find_all("h1", class_="title")
    paper['title'] = div_title[0].contents[0]

    #Get arXivID
    
    #Get authors
    div_authors = soup.find_all("ul", class_="authors")
    for div_author in div_authors:
        a_href_authors = div_author.find_all('a')
        for a_href_author in a_href_authors:
            paper['authors'].append(a_href_author.contents[0])

    #Get scites
    div_scites = soup.find_all("div", class_="scites")
    for scite in div_scites:
        a_href_names = scite.find_all('a')
        for a_href_name in a_href_names:
            paper['scites'].append(a_href_name.contents[0])

    return paper

# %%
#Test
url = 'https://scirate.com/arxiv/1612.06203'
get_paper_details(url)
# Out:
# {'arxivID': None,
#  'authors': ['Dominic J. Moylett', 'Noah Linden', 'Ashley Montanaro'],
#  'scites': ['Adam Paetznick',
#   'Andrew Childs',
#   'Anna Pappa',
#   'Aram Harrow',
#   'Ciarán Lee',
#   'Daniel Brod',
#   'Daniel Freeman',
#   'David Elkouss',
#   'David Gosset',
#   'David Gross',
#   'Dawei Ding',
#   'Dominic Williamson',
#   'Elizabeth Crosson',
#   'Evgeniy Zheltonozhskiy',
#   'Fabiano Andrade',
#   'Han-Hsuan Lin',
#   'Ion Nechita',
#   'Jamie Parkinson',
#   "Joe O'Gorman",
#   'Man-Hong Yung',
#   'Mario Berta',
#   'Māris Ozols',
#   'Martin Schwarz',
#   'Michael Jarret',
#   'mick',
#   'Noon van der Silk',
#   'Quntao Zhuang',
#   'Raul Garcia-Patron',
#   'Ryan L. Mann',
#   'Sam Roberts',
#   'Srinivasan',
#   'Stephen Bartlett',
#   'Stephen Jordan',
#   'Steve Flammia',
#   'Stuart Hadfield',
#   'Supartha Podder',
#   'Tom Wong',
#   'Tongyang Li',
#   'Varun Narasimhachar',
#   'Xin Wang',
#   'Yichen Huang',
#   'Yinan Li',
#   'Yong-Zhen Xu',
#   'Zak Webb',
#   'Zoltán Zimborás'],
#  'title': 'Quantum speedup of the Travelling Salesman Problem for bounded-degree graphs'}

# %%
def get_url_list(date, Range):
    """
    Input: date, range (specified as number of days behind date)
    Output: dictionary of link-dictionaries for papers published within those dates
            Scans the first 20 pages of scirate
    """
    paperlist = {}
    for p in range(1,21):
        url = 'https://scirate.com/?date='+str(date)+'&page='+str(p)+'&range='+str(Range)
        source = urllib.request.urlopen(url).read()
        soup = bs(source,'html.parser')
        
        listing_page = soup.find_all("div",class_="paperlist")
        div_titles = listing_page[0].find_all("div",class_="title")
        number = 50*(p-1) + 0
        for div_title in div_titles:
            a_href_title = div_title.find_all('a')[0]
            title = a_href_title.contents[0]
            url = "https://scirate.com"+ a_href_title['href']
            paperlist[str(number)] = {}
            paperlist[str(number)]['url'] = url
            number = number + 1

        length = len(paperlist)

    return paperlist

# %%
paperlist = get_url_list('2017-01-19','500')
paperlist
# Out:
# {'0': {'url': 'https://scirate.com/arxiv/1603.03039'},
#  '1': {'url': 'https://scirate.com/arxiv/1604.07450'},
#  '2': {'url': 'https://scirate.com/arxiv/1604.01790'},
#  '3': {'url': 'https://scirate.com/arxiv/1601.07601'},
#  '4': {'url': 'https://scirate.com/arxiv/1511.04206'},
#  '5': {'url': 'https://scirate.com/arxiv/1511.00657'},
#  '6': {'url': 'https://scirate.com/arxiv/1606.03140'},
#  '7': {'url': 'https://scirate.com/arxiv/1611.06999'},
#  '8': {'url': 'https://scirate.com/arxiv/1609.05537'},
#  '9': {'url': 'https://scirate.com/arxiv/1607.08473'},
#  '10': {'url': 'https://scirate.com/arxiv/1607.05256'},
#  '11': {'url': 'https://scirate.com/arxiv/1701.01062'},
#  '12': {'url': 'https://scirate.com/arxiv/1611.04471'},
#  '13': {'url': 'https://scirate.com/arxiv/1602.07674'},
#  '14': {'url': 'https://scirate.com/arxiv/1510.02082'},
#  '15': {'url': 'https://scirate.com/arxiv/1611.05450'},
#  '16': {'url': 'https://scirate.com/arxiv/1512.03547'},
#  '17': {'url': 'https://scirate.com/arxiv/1511.02306'},
#  '18': {'url': 'https://scirate.com/arxiv/1612.05903'},
#  '19': {'url': 'https://scirate.com/arxiv/1612.02437'},
#  '20': {'url': 'https://scirate.com/arxiv/1611.09274'},
#  '21': {'url': 'https://scirate.com/arxiv/1603.08675'},
#  '22': {'url': 'https://scirate.com/arxiv/1604.07422'},
#  '23': {'url': 'https://scirate.com/arxiv/1601.03030'},
#  '24': {'url': 'https://scirate.com/arxiv/1511.08506'},
#  '25': {'url': 'https://scirate.com/arxiv/1609.08579'},
#  '26': {'url': 'https://scirate.com/arxiv/1608.02600'},
#  '27': {'url': 'https://scirate.com/arxiv/1607.03236'},
#  '28': {'url': 'https://scirate.com/arxiv/1602.04768'},
#  '29': {'url': 'https://scirate.com/arxiv/1612.06203'},
#  '30': {'url': 'https://scirate.com/arxiv/1611.09347'},
#  '31': {'url': 'https://scirate.com/arxiv/1610.01664'},
#  '32': {'url': 'https://scirate.com/arxiv/1510.02769'},
#  '33': {'url': 'https://scirate.com/arxiv/1612.07330'},
#  '34': {'url': 'https://scirate.com/arxiv/1612.04795'},
#  '35': {'url': 'https://scirate.com/arxiv/1611.03790'},
#  '36': {'url': 'https://scirate.com/arxiv/1510.02619'},
#  '37': {'url': 'https://scirate.com/arxiv/1602.08828'},
#  '38': {'url': 'https://scirate.com/arxiv/1510.02767'},
#  '39': {'url': 'https://scirate.com/arxiv/1509.09180'},
#  '40': {'url': 'https://scirate.com/arxiv/1511.06526'},
#  '41': {'url': 'https://scirate.com/arxiv/1612.01011'},
#  '42': {'url': 'https://scirate.com/arxiv/1609.07877'},
#  '43': {'url': 'https://scirate.com/arxiv/1604.02804'},
#  '44': {'url': 'https://scirate.com/arxiv/1602.04145'},
#  '45': {'url': 'https://scirate.com/arxiv/1510.08447'},
#  '961': {'url': 'https://scirate.com/arxiv/1512.01634'},
#  '962': {'url': 'https://scirate.com/arxiv/1512.00732'},
#  '963': {'url': 'https://scirate.com/arxiv/1512.00661'},
#  '964': {'url': 'https://scirate.com/arxiv/1511.08893'},
#  '965': {'url': 'https://scirate.com/arxiv/1511.08253'},
#  '966': {'url': 'https://scirate.com/arxiv/1511.06016'},
#  '967': {'url': 'https://scirate.com/arxiv/1511.03316'},
#  '968': {'url': 'https://scirate.com/arxiv/1511.02596'},
#  '969': {'url': 'https://scirate.com/arxiv/1511.01851'},
#  '970': {'url': 'https://scirate.com/arxiv/1511.01433'},
#  '971': {'url': 'https://scirate.com/arxiv/1511.00552'},
#  '972': {'url': 'https://scirate.com/arxiv/1511.00293'},
#  '973': {'url': 'https://scirate.com/arxiv/1510.07815'},
#  '974': {'url': 'https://scirate.com/arxiv/1510.06888'},
#  '975': {'url': 'https://scirate.com/arxiv/1510.04430'},
#  '976': {'url': 'https://scirate.com/arxiv/1510.03064'},
#  '977': {'url': 'https://scirate.com/arxiv/1510.01309'},
#  '978': {'url': 'https://scirate.com/arxiv/1510.01272'},
#  '979': {'url': 'https://scirate.com/arxiv/1510.00010'},
#  '980': {'url': 'https://scirate.com/arxiv/1509.08134'},
#  '981': {'url': 'https://scirate.com/arxiv/1509.08094'},
#  '982': {'url': 'https://scirate.com/arxiv/1509.07456'},
#  '983': {'url': 'https://scirate.com/arxiv/1509.05692'},
#  '984': {'url': 'https://scirate.com/arxiv/1509.04279'},
#  '985': {'url': 'https://scirate.com/arxiv/1509.02749'},
#  '986': {'url': 'https://scirate.com/arxiv/1511.03509'},
#  '987': {'url': 'https://scirate.com/arxiv/1612.06373'},
#  '988': {'url': 'https://scirate.com/arxiv/1701.05152'},
#  '989': {'url': 'https://scirate.com/arxiv/1701.02936'},
#  '990': {'url': 'https://scirate.com/arxiv/1701.01755'},
#  '991': {'url': 'https://scirate.com/arxiv/1612.07734'},
#  '992': {'url': 'https://scirate.com/arxiv/1612.06828'},
#  '993': {'url': 'https://scirate.com/arxiv/1612.06012'},
#  '994': {'url': 'https://scirate.com/arxiv/1612.04837'},
#  '995': {'url': 'https://scirate.com/arxiv/1612.03148'},
#  '996': {'url': 'https://scirate.com/arxiv/1612.01952'},
#  '997': {'url': 'https://scirate.com/arxiv/1612.01199'},
#  '998': {'url': 'https://scirate.com/arxiv/1611.10020'},
#  '999': {'url': 'https://scirate.com/arxiv/1611.08104'}}

# %%
def get_all_papers(paperlist):
    """
    Input: dictionary of link-scite-dictionary
    Output: dictionary of paper-dictionaries
    """
    length = len(paperlist)
    for i in range(length):
        url_to_paper = paperlist[str(i)]['url']
        paper_details = get_paper_details(url_to_paper)
        paperlist[str(i)]['authors'] = paper_details['authors']
        paperlist[str(i)]['scites'] = paper_details['scites']
        paperlist[str(i)]['title'] = paper_details['title']
        paperlist[str(i)]['arxivID'] = paper_details['arxivID']
    return paperlist

# %%
#Test
scirate_papers = get_all_papers(paperlist)

# %%
def get_qip2017_accepted_titles():
    """
    Input: None
    Output: Dictionary of dictionaries, each representing a paper accepted to QIP 2017
                each inner dictionary containing title and authors
    """
    url = 'https://stationq.microsoft.com/qip-2017details/'
    source = urllib.request.urlopen(url).read()
    soup = bs(source,'html.parser')

    div_papers = soup.find_all('ul')

    plenary_talks_tags = div_papers[9]
    accepted_talks_tags = div_papers[10]

    plenary_talks_names = plenary_talks_tags.get_text()
    plenary_talks_papers = plenary_talks_names.split('\n')[1:-1]
    plenary_talks_dict = {}

    accepted_talks_names = accepted_talks_tags.get_text()
    accepted_talks_papers = accepted_talks_names.split('\n')[1:-1]
    accepted_talks_dict = {}

    counter = 0
    for name in plenary_talks_papers:
        split = name.split('—')
        plenary_talks_dict[str(counter)] = {}
        plenary_talks_dict[str(counter)]['title'] = split[0]
        list_names = split[1].split(',')
        plenary_talks_dict[str(counter)]['authors'] = []
        for list_name in list_names:
            plenary_talks_dict[str(counter)]['authors'].append(list_name.strip().replace('and ',''))
        counter += 1

    counter = 0
    for name in accepted_talks_papers:
        if name == "merged with":
            continue
        elif name == "and":
            continue
        else:
            split = name.split('—')
            accepted_talks_dict[str(counter)] = {}
            accepted_talks_dict[str(counter)]['title'] = split[0]
            if ',' in split[1]:
                list_names = split[1].split(',')
            else:
                list_names = split[1].split('and ')
            accepted_talks_dict[str(counter)]['authors'] = []
            for list_name in list_names:
                accepted_talks_dict[str(counter)]['authors'].append(list_name.strip().replace('and ',''))
            counter += 1

    return plenary_talks_dict, accepted_talks_dict

# %%
def get_qip2017_posters():
    """
    Input: None
    Output: Dictionary of dictionaries, each representing a paper accepted to QIP 2017
                each inner dictionary containing title and authors
    """
    url = 'https://stationq.microsoft.com/qip-2017details/'
    source = urllib.request.urlopen(url).read()
    soup = bs(source,'html.parser')

    div_papers = soup.find_all('ul')

    posters_tags = div_papers[11]

    posters_names = posters_tags.get_text()
    posters_papers = posters_names.split('\n')[1:-1]
    posters_dict = {}

    counter = 0
    for name in posters_papers:
        if name == "merged with":
            continue
        elif name == "and":
            continue
        else:
            split = name.split('—')
            posters_dict[str(counter)] = {}
            posters_dict[str(counter)]['title'] = split[0]
            if ',' in split[1]:
                list_names = split[1].split(',')
            else:
                list_names = split[1].split('and ')
            posters_dict[str(counter)]['authors'] = []
            for list_name in list_names:
                posters_dict[str(counter)]['authors'].append(list_name.strip().replace('and ',''))
            counter += 1

    return posters_dict

# %%
plenary_talks, accepted_talks = get_qip2017_accepted_titles()

# %%
rejected_talks = get_qip2017_posters()

# %%
#List of titles accepted to QIP
accepted_titles = []
for no_sci, paper_info in accepted_talks.items():
    accepted_titles.append(paper_info['title'])

#List of titles rejected from QIP
rejected_titles = []
for no_sci, paper_info in rejected_talks.items():
    rejected_titles.append(paper_info['title'])

#List of scite count for papers used to calculate avg, median, std_devn
accept_scite_count = []
reject_scite_count = []

for no_acc, details in scirate_papers.items():
    accept_match = difflib.get_close_matches(details['title'], accepted_titles, cutoff = 0.7)
    reject_match = difflib.get_close_matches(details['title'], rejected_titles, cutoff = 0.7)
    if accept_match != []:
        accept_scite_count.append(len(details['scites']))
    if reject_match != []:
        reject_scite_count.append(len(details['scites']))
    
accept_scite_count = np.array(accept_scite_count)
reject_scite_count = np.array(reject_scite_count)

accept_avg_scites = np.mean(accept_scite_count)
accept_median_scites = np.median(accept_scite_count)

reject_avg_scites = np.mean(reject_scite_count)
reject_median_scites = np.median(reject_scite_count)

print('\n-----------------------------------------------------\n')
print('------------ Accept stats ---------------------------')
print('\n-----------------------------------------------------\n')

print('Average number of scites for accepted papers: ' + str(accept_avg_scites))
print('Median number of scites for accepted papers: ' + str(accept_median_scites))

print('\n-----------------------------------------------------\n')
print('------------ Reject stats ---------------------------')
print('\n-----------------------------------------------------\n')

print('Average number of scites for rejected papers: ' + str(reject_avg_scites))
print('Median number of scites for rejected papers: ' + str(reject_median_scites))
# Out:
# -----------------------------------------------------
#
# ------------ Accept stats ---------------------------
#
# -----------------------------------------------------
#
# Average number of scites for accepted papers: 30.4166666667
# Median number of scites for accepted papers: 29.5
#
# -----------------------------------------------------
#
# ------------ Reject stats ---------------------------
#
# -----------------------------------------------------
#
# Average number of scites for rejected papers: 23.24
# Median number of scites for rejected papers: 21.0

# %%
def get_cabal():
    sciters = []
    for no_sci, details in scirate_papers.items():
        for sciter in details['scites']:
            sciters.append(sciter)

    sciters = set(sciters)

    score = {}

    for sciter in sciters:
        score[sciter] = [0,0]

    for no_acc, details in scirate_papers.items():
        accepted_match = difflib.get_close_matches(details['title'], accepted_titles, cutoff = 0.7)
        rejected_match = difflib.get_close_matches(details['title'], rejected_titles, cutoff = 0.7)
        if accepted_match != []:            
            for sciter in details['scites']:
                score[sciter][0] = score[sciter][0] + 1
                score[sciter][1] = score[sciter][1] + 1
        if rejected_match != []:
            for sciter in details['scites']:
                score[sciter][0] = score[sciter][0] - 1
                score[sciter][1] = score[sciter][1] + 1

    for name, score_tuple in score.items():
        if score_tuple[1] != 0:
            normalized_score = score_tuple[0]/score_tuple[1]
            score[name].append(normalized_score)
        elif score_tuple[1] == 0:
            score[name].append(-1)

    return score

# %%
cabal = get_cabal()

# %%
sorted(cabal.items(), key=lambda x:x[1][2])
# Out:
# [('Robie Hennigar', [0, 0, -1]),
#  ('Piers Lillystone', [0, 0, -1]),
#  ('Serge-Olivier Paquette', [0, 0, -1]),
#  ('Christian Gogolin ', [0, 0, -1]),
#  ('Jiajun Ma', [0, 0, -1]),
#  ('Deniz Stiegemann', [0, 0, -1]),
#  ('Jing-Yan Haw', [0, 0, -1]),
#  ('heather', [0, 0, -1]),
#  ('Ryuji Takagi', [-1, 1, -1.0]),
#  ('Teddy Megumi', [0, 0, -1]),
#  ('Daniel Nagaj', [-1, 1, -1.0]),
#  ('Marius Lewerenz', [0, 0, -1]),
#  ('Carlo Ottaviani', [0, 0, -1]),
#  ('Ken Brown', [0, 0, -1]),
#  ('Wolfgang Pfaff', [0, 0, -1]),
#  ('Senaida Hernández-Santana', [0, 0, -1]),
#  ('Hamed Mohammady', [-1, 1, -1.0]),
#  ('Nai-Hui Chia', [0, 0, -1]),
#  ('Sacha Schwarz', [0, 0, -1]),
#  ('Siva', [-1, 1, -1.0]),
#  ('Ashley Milsted', [-1, 1, -1.0]),
#  ('JGarre', [0, 0, -1]),
#  ('Ali Husain', [-1, 1, -1.0]),
#  ('Tomasz Darmetko', [0, 0, -1]),
#  ('Jiannis Pachos', [0, 0, -1]),
#  ('Mark Pearce', [0, 0, -1]),
#  ('mmanu', [0, 0, -1]),
#  ('Giuseppe Carleo', [0, 0, -1]),
#  ('Jean-Charles Vialatte', [0, 0, -1]),
#  ('David Perez-Garcia', [0, 0, -1]),
#  ('Zi-Wen Liu', [0, 0, -1]),
#  ('Robert J Chapman', [-1, 1, -1.0]),
#  ('Yuechi Ma', [0, 0, -1]),
#  ('Mark Mitchison', [0, 0, -1]),
#  ('Jonny', [-1, 1, -1.0]),
#  ('Anirudh Acharya', [0, 0, -1]),
#  ('Imdad Sardharwalla', [0, 0, -1]),
#  ('Tommaso Demarie', [0, 0, -1]),
#  ('Darius Bunandar', [0, 0, -1]),
#  ('Chris Self', [0, 0, -1]),
#  ('Nick Menicucci', [0, 0, -1]),
#  ('Lorenzo Cevolani', [0, 0, -1]),
#  ('Marius van Eck', [0, 0, -1]),
#  ('Zachary Eldredge', [0, 0, -1]),
#  ('Ariel Bendersky', [-1, 1, -1.0]),
#  ('Natalia Barker', [-1, 1, -1.0]),
#  ('Michael A. Sherbon', [0, 0, -1]),
#  ('JochenSz', [0, 0, -1]),
#  ('Filip Rozpędek', [0, 0, -1]),
#  ('Andrea Mari', [0, 0, -1]),
#  ('Toby Cubitt', [0, 0, -1]),
#  ('Nicolás Quesada', [0, 0, -1]),
#  ('resodiat', [0, 0, -1]),
#  ('Kun Fang', [-1, 1, -1.0]),
#  ('Pedro Ponte', [-1, 1, -1.0]),
#  ('Eric Metodiev', [0, 0, -1]),
#  ('Luke Heyfron', [0, 0, -1]),
#  ('hong', [0, 0, -1]),
#  ('Tomas Rybar', [0, 0, -1]),
#  ('Alex', [0, 0, -1]),
#  ('Jacques Pienaar', [0, 0, -1]),
#  ('Matthew McKague', [0, 0, -1]),
#  ('Vikesh Siddhu', [0, 0, -1]),
#  ('Michael Meiers', [0, 0, -1]),
#  ('John Smolin', [0, 0, -1]),
#  ('Abel Molina', [0, 0, -1]),
#  ('Anna Pappa', [-4, 4, -1.0]),
#  ('Yu Cai', [0, 0, -1]),
#  ('Gae Spedalieri', [0, 0, -1]),
#  ('Rick Muller', [0, 0, -1]),
#  ('Flavio Baccari', [-1, 1, -1.0]),
#  ('CS', [0, 0, -1]),
#  ('Yi-Chan Lee', [0, 0, -1]),
#  ('M. M. Taddei', [0, 0, -1]),
#  ('Frank E. S. Steinhoff', [0, 0, -1]),
#  ('SAFIR TK', [0, 0, -1]),
#  ('Jonathan Oppenehim', [0, 0, -1]),
#  ('William Hoza', [0, 0, -1]),
#  ('Alberto Peruzzo', [0, 0, -1]),
#  ('Cire Barr', [0, 0, -1]),
#  ('jfchung', [0, 0, -1]),
#  ('Kaushik Chakraborty', [0, 0, -1]),
#  ('mmtn', [0, 0, -1]),
#  ('Daniel Ranard', [0, 0, -1]),
#  ('Luispe Garcia-Pintos', [0, 0, -1]),
#  ('sujeet', [0, 0, -1]),
#  ('Xi Lin', [0, 0, -1]),
#  ('Tobias Osborne', [0, 0, -1]),
#  ('Steve Brierley', [0, 0, -1]),
#  ('Namit Anand', [0, 0, -1]),
#  ("Benjamin D'Anjou", [0, 0, -1]),
#  ('R. Prabhu', [0, 0, -1]),
#  ('Kepa', [0, 0, -1]),
#  ('Nayeli ', [0, 0, -1]),
#  ('John Selby', [0, 0, -1]),
#  ('Franziska Wegner', [0, 0, -1]),
#  ('Corsin Pfister', [0, 0, -1]),
#  ('Joel Klassen', [0, 0, -1]),
#  ('Pierre Naegelen', [0, 0, -1]),
#  ('Dmitry Kryuchkov', [0, 0, -1]),
#  ('Chris Sutherland', [0, 0, -1]),
#  ('Wei Xie', [0, 0, -1]),
#  ('Jayne Thompson', [0, 0, -1]),
#  ('Thomas Kalinowski', [0, 0, -1]),
#  ('Andrew Garner', [0, 0, -1]),
#  ('Valerio Peri', [-1, 1, -1.0]),
#  ('Kunal Sharma', [0, 0, -1]),
#  ('Cameron Duncan', [0, 0, -1]),
#  ('climaiw', [0, 0, -1]),
#  ('Ben Brown', [0, 0, -1]),
#  ('Lucas Celeri', [0, 0, -1]),
#  ('Alan C. Santos', [0, 0, -1]),
#  ('Florian John Curchod', [-1, 1, -1.0]),
#  ('Alexander Telfar', [0, 0, -1]),
#  ('Joe Renes', [0, 0, -1]),
#  ('Diogo O. Soares-Pinto', [-1, 1, -1.0]),
#  ('junping shao', [0, 0, -1]),
#  ('Jamie Parkinson', [0, 0, -1]),
#  ('Evgeniy Zheltonozhskiy', [0, 0, -1]),
#  ('cyclone', [0, 0, -1]),
#  ('Haoyu Qi', [0, 0, -1]),
#  ('tasuen', [0, 0, -1]),
#  ('Maciej Stankiewicz', [-2, 2, -1.0]),
#  ('kevin', [0, 0, -1]),
#  ('Ethan Brown', [0, 0, -1]),
#  ('Troy Lee', [0, 0, -1]),
#  ('Shin-Liang Chen', [-1, 1, -1.0]),
#  ('Alireza Poostindouz', [0, 0, -1]),
#  ('zhchung', [0, 0, -1]),
#  ('Lei Wang', [0, 0, -1]),
#  ('Simon Burton', [0, 0, -1]),
#  ('Matt Hastings', [0, 0, -1]),
#  ('Samuel Wilkinson', [0, 0, -1]),
#  ('David Newman', [0, 0, -1]),
#  ('Leon Loveridge', [0, 0, -1]),
#  ('Zhehao Dai', [0, 0, -1]),
#  ('Nicolò Ginatta', [-2, 2, -1.0]),
#  ('Leonel Morejón ', [0, 0, -1]),
#  ('Fu Wenbo', [0, 0, -1]),
#  ('John K', [-1, 1, -1.0]),
#  ('Michael Wolf', [0, 0, -1]),
#  ('Andrea Rocchetto', [0, 0, -1]),
#  ('Bill Plick', [0, 0, -1]),
#  ('Meng Fei', [-2, 2, -1.0]),
#  ('Guillaume aubrun', [0, 0, -1]),
#  ('Juan Carrasquilla', [-1, 1, -1.0]),
#  ('Chris Cesare', [0, 0, -1]),
#  ('Xiao-Ming Lu', [0, 0, -1]),
#  ('Alex Monras', [0, 0, -1]),
#  ('Santiago Casas', [0, 0, -1]),
#  ('Jordi Tura Brugués', [0, 0, -1]),
#  ('Alex Bullivant', [0, 0, -1]),
#  ('Matthew Graydon', [0, 0, -1]),
#  ('Shuhao Liu', [-1, 1, -1.0]),
#  ('Piotr Gawron', [0, 0, -1]),
#  ('Roberto Di Candia', [0, 0, -1]),
#  ('allison sachs', [0, 0, -1]),
#  ('Akihiro Mizutani', [0, 0, -1]),
#  ('Bogdan Grechuk', [0, 0, -1]),
#  ('Mafalda', [0, 0, -1]),
#  ('praimesl', [0, 0, -1]),
#  ('kim hsieh', [0, 0, -1]),
#  ('Rodrigo Gomez', [0, 0, -1]),
#  ('Peter Morgan', [0, 0, -1]),
#  ('Jonas Helsen', [0, 0, -1]),
#  ("Ryan O'Donnell", [0, 0, -1]),
#  ('Jennifer Radtke', [0, 0, -1]),
#  ('Pranav Rajpurkar', [0, 0, -1]),
#  ('Pablo Ibieta', [0, 0, -1]),
#  ('Antoine Tilloy', [0, 0, -1]),
#  ('Arnaud Carignan-Dugas', [0, 0, -1]),
#  ('Riccardo Laurenza', [0, 0, -1]),
#  ('Ernesto Galvão', [0, 0, -1]),
#  ('Ioannis Kogias', [-2, 2, -1.0]),
#  ('phigeasi', [0, 0, -1]),
#  ('Raj Kunkolienkar', [0, 0, -1]),
#  ('Isaac Kim', [-1, 1, -1.0]),
#  ('Christos Gagatsos', [0, 0, -1]),
#  ('Thomas Alexander', [0, 0, -1]),
#  ('Wilson Brenna', [-1, 1, -1.0]),
#  ('abdulghani hamood', [0, 0, -1]),
#  ('Tanay Mehta', [0, 0, -1]),
#  ('Artur Malabarba', [0, 0, -1]),
#  ('Filip Ącao', [0, 0, -1]),
#  ('Diane Donovan', [0, 0, -1]),
#  ('Ian Hincks', [0, 0, -1]),
#  ('Shengshi Pang', [0, 0, -1]),
#  ('clouslih', [0, 0, -1]),
#  ('Feihu Xu', [0, 0, -1]),
#  ('Guillaume Verdon-Akzam', [-1, 1, -1.0]),
#  ('Jon Yard', [0, 0, -1]),
#  ('Sai', [0, 0, -1]),
#  ('Yfke Dulek', [0, 0, -1]),
#  ('parsiad', [0, 0, -1]),
#  ('Евгений Вихров', [0, 0, -1]),
#  ('Robin Harper', [-1, 1, -1.0]),
#  ('Christopher McNally', [0, 0, -1]),
#  ('Eric Cavalcanti', [-3, 3, -1.0]),
#  ('Damian Steiger', [0, 0, -1]),
#  ('Yiyang Zhang', [0, 0, -1]),
#  ('Yi-Cong Zheng', [0, 0, -1]),
#  ('Zheshen Zhang', [-1, 1, -1.0]),
#  ('Alex Wozniakowski', [0, 0, -1]),
#  ('asif shakeel', [0, 0, -1]),
#  ('Saoussen Mbarek', [0, 0, -1]),
#  ('Harrison Ball', [0, 0, -1]),
#  ('Łukasz Pawela', [-1, 1, -1.0]),
#  ('Jesse Everett', [0, 0, -1]),
#  ('Cristi Stoica', [0, 0, -1]),
#  ('Akib Karim', [0, 0, -1]),
#  ('Sam Morley-Short', [0, 0, -1]),
#  ('Victor V Albert', [0, 0, -1]),
#  ('Sarah Kaiser', [0, 0, -1]),
#  ('David Jennings', [-1, 1, -1.0]),
#  ('Michael Tolan', [-2, 2, -1.0]),
#  ('Whei Yeap', [0, 0, -1]),
#  ('Guillaume Aubrun', [0, 0, -1]),
#  ('Daniel Springer', [0, 0, -1]),
#  ('Jhonathan Romero', [0, 0, -1]),
#  ('Eddie Schoute', [-1, 1, -1.0]),
#  ('Brian Swingle', [0, 0, -1]),
#  ('Han Xiao', [0, 0, -1]),
#  ('Andrew W Simmons', [0, 0, -1]),
#  ('Siong Thye  Goh', [-1, 1, -1.0]),
#  ('Xiaobin Zhao', [0, 0, -1]),
#  ('Karl Joulain', [0, 0, -1]),
#  ('Joe Fitzsimons', [0, 0, -1]),
#  ('Xiao Yuan', [0, 0, -1]),
#  ('Ivan Coulamy', [0, 0, -1]),
#  ('Jonathan Richens', [0, 0, -1]),
#  ('John B. DeBrota', [0, 0, -1]),
#  ('Omar Shehab', [0, 0, -1]),
#  ('wiadealo', [0, 0, -1]),
#  ('Aravinda ', [0, 0, -1]),
#  ('Filippo Miatto', [0, 0, -1]),
#  ('Pawel Caputa', [0, 0, -1]),
#  ('phaeladr', [0, 0, -1]),
#  ('Benoit Descamps', [0, 0, -1]),
#  ('Murphy Yuezhen Niu', [-1, 1, -1.0]),
#  ('Edgar A Aguilar', [0, 0, -1]),
#  ('Gian Giacomo Guerreschi', [0, 0, -1]),
#  ('Deepak Vaid', [0, 0, -1]),
#  ('Arkin Tikku', [0, 0, -1]),
#  ('Cosmo Lupo', [0, 0, -1]),
#  ('Matty Hoban', [0, 0, -1]),
#  ('ghadir.jafari', [0, 0, -1]),
#  ('Bassam Helou', [0, 0, -1]),
#  ('Mankei Tsang', [0, 0, -1]),
#  ('Miroslav Jezek', [0, 0, -1]),
#  ('Blake Stacey', [0, 0, -1]),
#  ('René Schwonnek', [-2, 4, -0.5]),
#  ('Ciara Morgan', [-4, 8, -0.5]),
#  ('Miles Stoudenmire', [-2, 4, -0.5]),
#  ('Leander Fiedler', [-6, 12, -0.5]),
#  ('Quntao Zhuang', [-3, 7, -0.42857142857142855]),
#  ('Mark Howard', [-6, 14, -0.42857142857142855]),
#  ('Cécilia', [-1, 3, -0.3333333333333333]),
#  ('Geza Giedke', [-1, 3, -0.3333333333333333]),
#  ('Rui Chao', [-1, 3, -0.3333333333333333]),
#  ('Jonas Anderson', [-1, 3, -0.3333333333333333]),
#  ('David Tuckett', [-1, 3, -0.3333333333333333]),
#  ('Gael Sentís', [-1, 3, -0.3333333333333333]),
#  ('Christian Majenz', [-4, 12, -0.3333333333333333]),
#  ('Johannes Bausch', [-1, 3, -0.3333333333333333]),
#  ('Mark Girard', [-2, 8, -0.25]),
#  ('Richard Kueng', [-2, 8, -0.25]),
#  ('Gianni', [-1, 5, -0.2]),
#  ('Dominik Hangleiter', [-1, 5, -0.2]),
#  ('Fernando de Melo', [-1, 5, -0.2]),
#  ('Alessandro', [-1, 5, -0.2]),
#  ('Patrick Hayden', [-4, 22, -0.18181818181818182]),
#  ('Mario Berta', [-6, 36, -0.16666666666666666]),
#  ('Mark M. Wilde', [-2, 12, -0.16666666666666666]),
#  ('Kenneth Goodenough', [-4, 26, -0.15384615384615385]),
#  ('Grant Salton', [-1, 7, -0.14285714285714285]),
#  ('Florian Speelman', [-5, 45, -0.1111111111111111]),
#  ('Marcus P da Silva', [-1, 9, -0.1111111111111111]),
#  ('Angelo Lucia', [-2, 18, -0.1111111111111111]),
#  ('Marco Tomamichel', [-4, 44, -0.09090909090909091]),
#  ('Romain Alléaume', [-1, 11, -0.09090909090909091]),
#  ('Ninnat Dangniam', [-1, 13, -0.07692307692307693]),
#  ('Marco Piani', [-2, 34, -0.058823529411764705]),
#  ('Juan Miguel Arrazola', [-1, 19, -0.05263157894736842]),
#  ('Raul Garcia-Patron', [-2, 42, -0.047619047619047616]),
#  ('Man-Hong Yung', [-4, 86, -0.046511627906976744]),
#  ('Dominic Williamson', [-1, 25, -0.04]),
#  ('Zoltán Zimborás', [-2, 74, -0.02702702702702703]),
#  ('Noon van der Silk', [-2, 98, -0.02040816326530612]),
#  ('Guang Hao Low', [0, 2, 0.0]),
#  ('Emmett Owen', [0, 4, 0.0]),
#  ('Nikolas Breuckmann', [0, 18, 0.0]),
#  ('Aram Harrow', [0, 88, 0.0]),
#  ('Nathan Wiebe', [0, 2, 0.0]),
#  ('Jeroen Zuiddam', [0, 4, 0.0]),
#  ('Xun Gao', [0, 14, 0.0]),
#  ('Roger Melko', [0, 4, 0.0]),
#  ('Ryan Babbush', [0, 2, 0.0]),
#  ('David Aasen', [0, 4, 0.0]),
#  ('Sepehr Nezami', [0, 2, 0.0]),
#  ('Daniel Stilck Franca', [0, 4, 0.0]),
#  ('Chris', [0, 2, 0.0]),
#  ('Daniel Suess', [0, 6, 0.0]),
#  ('Jim Harrington', [0, 2, 0.0]),
#  ('Ciarán Lee', [0, 4, 0.0]),
#  ('Shantanav Chakraborty', [0, 2, 0.0]),
#  ('Koen Groenland', [0, 2, 0.0]),
#  ('You Zhou', [0, 4, 0.0]),
#  ('Christopher Thomas Chubb', [0, 16, 0.0]),
#  ('Siddhartha Das', [0, 10, 0.0]),
#  ('Alvaro M. Alhambra', [0, 8, 0.0]),
#  ('Nelly', [0, 2, 0.0]),
#  ('Thomas Smith', [0, 2, 0.0]),
#  ('Beni Yoshida', [0, 8, 0.0]),
#  ('Cupjin Huang', [0, 4, 0.0]),
#  ('Stefano Pirandola ', [0, 2, 0.0]),
#  ('Nayeli A. Rodriguez Briones', [0, 2, 0.0]),
#  ('Laura Mančinska', [0, 2, 0.0]),
#  ('Ish Dhand', [0, 6, 0.0]),
#  ('mick', [2, 66, 0.030303030303030304]),
#  ('David Elkouss', [2, 60, 0.03333333333333333]),
#  ('Xin Wang', [1, 29, 0.034482758620689655]),
#  ('Zak Webb', [1, 27, 0.037037037037037035]),
#  ('Stephen Bartlett', [2, 48, 0.041666666666666664]),
#  ('Christopher Chamberland', [1, 17, 0.058823529411764705]),
#  ('Stephen Jordan', [3, 51, 0.058823529411764705]),
#  ('Jens Eisert', [1, 13, 0.07692307692307693]),
#  ('HA', [2, 24, 0.08333333333333333]),
#  ('Steve Flammia', [4, 46, 0.08695652173913043]),
#  ('Frédéric Grosshans', [2, 22, 0.09090909090909091]),
#  ('Fabiano Andrade', [2, 20, 0.1]),
#  ('Christoph Hirche', [4, 38, 0.10526315789473684]),
#  ('Srinivasan', [4, 38, 0.10526315789473684]),
#  ('Stuart Hadfield', [2, 18, 0.1111111111111111]),
#  ('Juan Bermejo-Vega', [1, 9, 0.1111111111111111]),
#  ('Michal Oszmaniec', [2, 16, 0.125]),
#  ('Varun Narasimhachar', [2, 16, 0.125]),
#  ('Ion Nechita', [2, 16, 0.125]),
#  ('Jacob Bridgeman', [1, 7, 0.14285714285714285]),
#  ('Shelby Kimmel', [2, 14, 0.14285714285714285]),
#  ('Robin Blume-Kohout', [1, 7, 0.14285714285714285]),
#  ('Karen Hovhannisyan', [2, 14, 0.14285714285714285]),
#  ('Adam Paetznick', [3, 19, 0.15789473684210525]),
#  ('Māris Ozols', [10, 62, 0.16129032258064516]),
#  ('courtney brell', [4, 24, 0.16666666666666666]),
#  ('Felix Leditzky', [2, 12, 0.16666666666666666]),
#  ('MJKastoryano', [2, 12, 0.16666666666666666]),
#  ('Cedric Yen-Yu Lin', [7, 41, 0.17073170731707318]),
#  ('Robert Raussendorf', [1, 5, 0.2]),
#  ('Michael Jarret', [1, 5, 0.2]),
#  ('Nicolas Delfosse', [1, 5, 0.2]),
#  ('Sam Roberts', [2, 10, 0.2]),
#  ('Chris Ferrie', [1, 5, 0.2]),
#  ('Anand Natarajan', [5, 23, 0.21739130434782608]),
#  ('Ryan L. Mann', [5, 23, 0.21739130434782608]),
#  ("Tomas Jochym-O'Connor", [4, 18, 0.2222222222222222]),
#  ('David Gross', [4, 18, 0.2222222222222222]),
#  ('Henry Yuen', [7, 29, 0.2413793103448276]),
#  ('Tom Bannink', [2, 8, 0.25]),
#  ('Theodore Yoder', [2, 8, 0.25]),
#  ('Nicole Yunger Halpern', [2, 8, 0.25]),
#  ('Andrew Childs', [8, 32, 0.25]),
#  ('David Mesterhazy', [4, 16, 0.25]),
#  ('Tongyang Li', [6, 22, 0.2727272727272727]),
#  ('Marc Kaplan', [3, 11, 0.2727272727272727]),
#  ('Yichen Huang', [4, 14, 0.2857142857142857]),
#  ('Eleanor Rieffel', [4, 14, 0.2857142857142857]),
#  ('David Gosset', [5, 17, 0.29411764705882354]),
#  ('Elizabeth Crosson', [11, 37, 0.2972972972972973]),
#  ('Jianxin Chen', [4, 12, 0.3333333333333333]),
#  ('Charles Hill', [1, 3, 0.3333333333333333]),
#  ('Ivan Supic', [1, 3, 0.3333333333333333]),
#  ('Valentin Zauner-Stauber', [1, 3, 0.3333333333333333]),
#  ('David Fine', [1, 3, 0.3333333333333333]),
#  ('Daniel Brod', [1, 3, 0.3333333333333333]),
#  ('Manoj Gowda', [1, 3, 0.3333333333333333]),
#  ('Ching-Yi Lai', [1, 3, 0.3333333333333333]),
#  ('MSK', [1, 3, 0.3333333333333333]),
#  ('Chris Granade', [1, 3, 0.3333333333333333]),
#  ('Niel de Beaudrap', [1, 3, 0.3333333333333333]),
#  ('JRW', [1, 3, 0.3333333333333333]),
#  ('Hakop Pashayan', [1, 3, 0.3333333333333333]),
#  ('Manuel Rodriguez', [1, 3, 0.3333333333333333]),
#  ('Nagayama Shota', [1, 3, 0.3333333333333333]),
#  ('Kaushik Seshadreesan', [3, 9, 0.3333333333333333]),
#  ('Anurag Anshu', [2, 6, 0.3333333333333333]),
#  ('Tom Cooney', [1, 3, 0.3333333333333333]),
#  ('Earl Campbell', [3, 9, 0.3333333333333333]),
#  ('Nana Liu', [1, 3, 0.3333333333333333]),
#  ('Martin Schwarz', [11, 31, 0.3548387096774194]),
#  ('Vincent Russo', [7, 19, 0.3684210526315789]),
#  ('Adam Bouland', [7, 19, 0.3684210526315789]),
#  ('Mohammad Bavarian', [5, 13, 0.38461538461538464]),
#  ('Dawei Ding', [10, 26, 0.38461538461538464]),
#  ('Han-Hsuan Lin', [9, 23, 0.391304347826087]),
#  ('Ben', [9, 23, 0.391304347826087]),
#  ('Andras Molnar', [3, 7, 0.42857142857142855]),
#  ('Terry', [5, 11, 0.45454545454545453]),
#  ('Vadym Kliuchnikov', [5, 11, 0.45454545454545453]),
#  ('Anirudh Krishna', [5, 11, 0.45454545454545453]),
#  ('Fernando Pastawski', [2, 4, 0.5]),
#  ('Anthony Leverrier', [4, 8, 0.5]),
#  ('Ben Criger', [4, 8, 0.5]),
#  ('Ashley', [2, 4, 0.5]),
#  ('Tom Wong', [6, 12, 0.5]),
#  ('Maria Kieferova', [5, 9, 0.5555555555555556]),
#  ('Kun Wang', [3, 5, 0.6]),
#  ('John Napp', [3, 5, 0.6]),
#  ('Yinan Li', [3, 5, 0.6]),
#  ('Supartha Podder', [4, 6, 0.6666666666666666]),
#  ('Todd Brun', [4, 6, 0.6666666666666666]),
#  ('Matthew Coudron', [4, 6, 0.6666666666666666]),
#  ('Hari Krovi', [5, 7, 0.7142857142857143]),
#  ('Yupan Liu', [7, 9, 0.7777777777777778]),
#  ('Dave Bacon', [7, 9, 0.7777777777777778]),
#  ('Mile Gu', [1, 1, 1.0]),
#  ('Hardik Bansal', [1, 1, 1.0]),
#  ('Jon Leiner', [2, 2, 1.0]),
#  ('Mike Vasmer', [1, 1, 1.0]),
#  ('lior eldar', [3, 3, 1.0]),
#  ('Chris Perry', [2, 2, 1.0]),
#  ('Yong-Zhen Xu', [3, 3, 1.0]),
#  ('Andreas', [2, 2, 1.0]),
#  ('Viv Kendon', [4, 4, 1.0]),
#  ('Yudong Cao', [1, 1, 1.0]),
#  ('Yingkai Ouyang', [5, 5, 1.0]),
#  ('Peter Wittek', [2, 2, 1.0]),
#  ('Arne Grimsmo', [2, 2, 1.0]),
#  ('Carlo Sparaciari', [1, 1, 1.0]),
#  ('Wissam Chemissany', [1, 1, 1.0]),
#  ('Padraic Calpin', [4, 4, 1.0]),
#  ('Konstantinos Meichanetzidis', [1, 1, 1.0]),
#  ('Nikolai Miklin', [1, 1, 1.0]),
#  ('Lidia del Rio', [1, 1, 1.0]),
#  ('Lars Jaffke', [1, 1, 1.0]),
#  ('Raffaele Santagati', [1, 1, 1.0]),
#  ('Alan Robertson', [1, 1, 1.0]),
#  ('Salvatore Mandrà', [2, 2, 1.0]),
#  ('James D. Whitfield', [1, 1, 1.0]),
#  ('Thomas D. Galley', [1, 1, 1.0]),
#  ('Danial Dervovic', [1, 1, 1.0]),
#  ('Andris', [2, 2, 1.0]),
#  ('Federico Spedalieri', [1, 1, 1.0]),
#  ('Yuxiang Yang', [2, 2, 1.0]),
#  ('Bhaskar Roy', [4, 4, 1.0]),
#  ("Joe O'Gorman", [4, 4, 1.0]),
#  ('Zhaohui Wei', [1, 1, 1.0]),
#  ('Licheng Richard Zhu', [1, 1, 1.0]),
#  ('Spring', [1, 1, 1.0]),
#  ('Radek Adamczak', [1, 1, 1.0]),
#  ('George Barron', [1, 1, 1.0]),
#  ('Vlad Gheorghiu', [3, 3, 1.0]),
#  ('Andreas Ketterer', [1, 1, 1.0]),
#  ('Ritabrata Sengupta', [1, 1, 1.0]),
#  ('Zach Cristina', [1, 1, 1.0]),
#  ('Angela Karanjai', [1, 1, 1.0]),
#  ('Lyndon Maydwell', [1, 1, 1.0]),
#  ('sattath', [1, 1, 1.0]),
#  ('Joshua Lockhart', [2, 2, 1.0]),
#  ('Matthias Bal', [1, 1, 1.0]),
#  ('gae spedalieri', [1, 1, 1.0]),
#  ('Bang-Hai Wang', [4, 4, 1.0]),
#  ('Jaroslaw Miszczak', [1, 1, 1.0]),
#  ('Frederic Magniez', [3, 3, 1.0]),
#  ('Dave Wecker', [1, 1, 1.0]),
#  ('Milad', [1, 1, 1.0]),
#  ('Zhang-qi Yin', [1, 1, 1.0]),
#  ('Travis Scholten', [1, 1, 1.0]),
#  ('Natasha Gabay', [1, 1, 1.0]),
#  ('Elton Yechao Zhu', [1, 1, 1.0]),
#  ('Dominic J. Moylett', [1, 1, 1.0]),
#  ('Daniel Freeman', [3, 3, 1.0]),
#  ('Jānis Iraids', [1, 1, 1.0]),
#  ('Srinivasan. A', [1, 1, 1.0]),
#  ('Mehdi Ahmadi', [1, 1, 1.0]),
#  ('Sander Gribling', [1, 1, 1.0]),
#  ('Rafael Alexander', [2, 2, 1.0]),
#  ('Mario', [1, 1, 1.0]),
#  ('Pavithran Sridharan Iyer', [1, 1, 1.0]),
#  ('David Stephen', [1, 1, 1.0]),
#  ('Mark Tyson', [2, 2, 1.0]),
#  ('Barbara Terhal', [3, 3, 1.0])]

# %%
scirate_titles = []
for no_sci, paper_details in scirate_papers.items():
    scirate_titles.append(paper_details['title'])

unaccounted_for = dict(accepted_talks)

for no_acc, details in accepted_talks.items():
    accept_match = difflib.get_close_matches(details['title'], scirate_titles, cutoff = 0.7)
    if accept_match != []:
        del unaccounted_for[no_acc]

for key, value in unaccounted_for.items():
    print(value['title'])
